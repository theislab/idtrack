# %% [markdown]
# # Initialize Graph Object

# %%
import sys
sys.path.append("/Users/kemalinecik/git_nosync/idtrack")

import os
import time
import pickle
import idtrack
import copy

# %%
# !ls -l /Users/kemalinecik/Downloads/idtrack_temp
# Out:
# total 61807256
# -rw-r--r--@ 1 kemalinecik  staff  15889966491 May 27 17:26 homo_sapiens_assembly-37.h5
# -rw-r--r--@ 1 kemalinecik  staff  15755222398 May 27 14:08 homo_sapiens_assembly-38.h5
# -rw-r--r--@ 1 kemalinecik  staff        65514 May 27 17:59 homo_sapiens_externals_modified.yml
# -rw-r--r--@ 1 kemalinecik  staff        55077 May 27 17:26 homo_sapiens_externals_template.yml

# %%
local_dir = "/Users/kemalinecik/Downloads/idtrack_temp"
idt = idtrack.API(local_repository=local_dir)
idt.configure_logger()

# %%
# %%time
organism_formal_name, last_ensembl_release = idt.get_ensembl_organism("homo sapiens")
organism_formal_name, last_ensembl_release
# Out:
# 2025-05-27 18:08:28 INFO:verify_organism: Ensembl Rest API query to get the organism names and associated releases.
# CPU times: user 18.8 ms, sys: 9.96 ms, total: 28.8 ms
# Wall time: 511 ms
# ('homo_sapiens', 114)

# %%
# %%time
idt.initialize_graph(organism_name='homo_sapiens', last_ensembl_release=114, return_test=True)
# Out:
# 2025-05-27 18:08:29 INFO:graph_maker: The graph is being constructed: /Users/kemalinecik/Downloads/idtrack_temp/graph_homo_sapiens_min79_max114_narrow.pickle
# 2025-05-27 18:08:29 INFO:graph_maker: Graph is being created: gene
# 2025-05-27 18:08:29 INFO:database_manager: Raw table for `mapping_session` on ensembl release `114` was downloaded.
# 2025-05-27 18:08:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_mysql_mapping_session`
# 2025-05-27 18:08:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_versioninfo_gene`
# 2025-05-27 18:09:09 INFO:database_manager: Raw table for `stable_id_event` on ensembl release `114` was downloaded.
# 2025-05-27 18:09:09 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_mysql_stable_id_event`
# 2025-05-27 18:10:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_idhistory_narrow_gene`
# 2025-05-27 18:10:18 WARNING:graph_maker: Edge weights ignored due to duplicate entries: 2.
# 2025-05-27 18:10:18 INFO:graph_maker: Edges between across different IDs and self loops are being added.
# 2025-05-27 18:10:20 INFO:graph_maker: Edges between the same IDs are being added.
# 2025-05-27 18:10:34 WARNING:graph_maker: Retired ID come alive again: 3.
# 2025-05-27 18:10:34 INFO:graph_maker: Edges showing the retirement of IDs are being added.
# 2025-05-27 18:10:39 INFO:graph_maker: Problematic nodes in Ensembl ID history are being removed.
# 2025-05-27 18:10:44 WARNING:graph_maker: Nodes are deleted due to Ensembl ID history mistake: 4.
# 2025-05-27 18:10:44 INFO:graph_maker: Self-loops for latest release entries are being added.
# 2025-05-27 18:10:46 INFO:graph_maker: Node attributes are being added.
# 2025-05-27 18:10:46 INFO:graph_maker: Graph is being created: transcript
# 2025-05-27 18:10:52 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_versioninfo_transcript`
# 2025-05-27 18:10:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_idhistory_narrow_transcript`
# 2025-05-27 18:11:12 INFO:graph_maker: Edges between across different IDs and self loops are being added.
# 2025-05-27 18:11:17 INFO:graph_maker: Edges between the same IDs are being added.
# 2025-05-27 18:12:22 WARNING:graph_maker: Retired ID come alive again: 5.
# 2025-05-27 18:12:22 INFO:graph_maker: Edges showing the retirement of IDs are being added.
# 2025-05-27 18:12:42 INFO:graph_maker: Problematic nodes in Ensembl ID history are being removed.
# 2025-05-27 18:13:01 INFO:graph_maker: Self-loops for latest release entries are being added.
# 2025-05-27 18:13:10 INFO:graph_maker: Node attributes are being added.
# 2025-05-27 18:13:15 INFO:graph_maker: Graph is being created: translation
# 2025-05-27 18:13:18 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_versioninfo_translation`
# 2025-05-27 18:13:25 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_idhistory_narrow_translation`
# 2025-05-27 18:13:26 WARNING:graph_maker: Edge weights ignored due to duplicate entries: 4.
# 2025-05-27 18:13:26 INFO:graph_maker: Edges between across different IDs and self loops are being added.
# 2025-05-27 18:13:27 INFO:graph_maker: Edges between the same IDs are being added.
# 2025-05-27 18:13:49 WARNING:graph_maker: Retired ID come alive again: 4.
# 2025-05-27 18:13:49 INFO:graph_maker: Edges showing the retirement of IDs are being added.
# 2025-05-27 18:13:56 INFO:graph_maker: Problematic nodes in Ensembl ID history are being removed.
# 2025-05-27 18:14:05 WARNING:graph_maker: Nodes are deleted due to Ensembl ID history mistake: 1.
# 2025-05-27 18:14:05 INFO:graph_maker: Self-loops for latest release entries are being added.
# 2025-05-27 18:14:08 INFO:graph_maker: Node attributes are being added.
# 2025-05-27 18:14:09 WARNING:graph_maker: Intersecting Ensembl nodes: Nodes in 'transcript' will be replaced by 'translation': 'ENST00000515292.1'.
# 2025-05-27 18:14:12 INFO:graph_maker: Establishing connection between different forms.
# 2025-05-27 18:14:12 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_processed_idsraw_gene_transcript`
# 2025-05-27 18:14:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_processed_idsraw_translation_transcript`
# 2025-05-27 18:14:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_common_relationcurrent`
# 2025-05-27 18:14:26 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_processed_idsraw_gene_transcript`
# 2025-05-27 18:14:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_processed_idsraw_translation_transcript`
# 2025-05-27 18:14:30 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_common_relationcurrent`
# 2025-05-27 18:14:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_processed_idsraw_gene_transcript`
# 2025-05-27 18:14:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_processed_idsraw_translation_transcript`
# 2025-05-27 18:14:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_common_relationcurrent`
# 2025-05-27 18:14:52 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_processed_idsraw_gene_transcript`
# 2025-05-27 18:14:53 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_processed_idsraw_translation_transcript`
# 2025-05-27 18:14:55 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_common_relationcurrent`
# 2025-05-27 18:15:04 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_processed_idsraw_gene_transcript`
# 2025-05-27 18:15:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_processed_idsraw_translation_transcript`
# 2025-05-27 18:15:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_common_relationcurrent`
# 2025-05-27 18:15:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_processed_idsraw_gene_transcript`
# 2025-05-27 18:15:17 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_processed_idsraw_translation_transcript`
# 2025-05-27 18:15:19 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_common_relationcurrent`
# 2025-05-27 18:15:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_processed_idsraw_gene_transcript`
# 2025-05-27 18:15:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_processed_idsraw_translation_transcript`
# 2025-05-27 18:15:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_common_relationcurrent`
# 2025-05-27 18:15:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_processed_idsraw_gene_transcript`
# 2025-05-27 18:15:42 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_processed_idsraw_translation_transcript`
# 2025-05-27 18:15:44 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_common_relationcurrent`
# 2025-05-27 18:15:53 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_processed_idsraw_gene_transcript`
# 2025-05-27 18:15:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_processed_idsraw_translation_transcript`
# 2025-05-27 18:15:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_common_relationcurrent`
# 2025-05-27 18:16:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_processed_idsraw_gene_transcript`
# 2025-05-27 18:16:06 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_processed_idsraw_translation_transcript`
# 2025-05-27 18:16:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_common_relationcurrent`
# 2025-05-27 18:16:17 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_processed_idsraw_gene_transcript`
# 2025-05-27 18:16:18 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_processed_idsraw_translation_transcript`
# 2025-05-27 18:16:20 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_common_relationcurrent`
# 2025-05-27 18:16:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_processed_idsraw_gene_transcript`
# 2025-05-27 18:16:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_processed_idsraw_translation_transcript`
# 2025-05-27 18:16:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_common_relationcurrent`
# 2025-05-27 18:16:42 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_processed_idsraw_gene_transcript`
# 2025-05-27 18:16:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_processed_idsraw_translation_transcript`
# 2025-05-27 18:16:45 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_common_relationcurrent`
# 2025-05-27 18:16:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_processed_idsraw_gene_transcript`
# 2025-05-27 18:16:55 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_processed_idsraw_translation_transcript`
# 2025-05-27 18:16:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_common_relationcurrent`
# 2025-05-27 18:17:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_processed_idsraw_gene_transcript`
# 2025-05-27 18:17:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_processed_idsraw_translation_transcript`
# 2025-05-27 18:17:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_common_relationcurrent`
# 2025-05-27 18:17:20 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_processed_idsraw_gene_transcript`
# 2025-05-27 18:17:21 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_processed_idsraw_translation_transcript`
# 2025-05-27 18:17:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_common_relationcurrent`
# 2025-05-27 18:17:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_processed_idsraw_gene_transcript`
# 2025-05-27 18:17:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_processed_idsraw_translation_transcript`
# 2025-05-27 18:17:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_common_relationcurrent`
# 2025-05-27 18:17:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_processed_idsraw_gene_transcript`
# 2025-05-27 18:17:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_processed_idsraw_translation_transcript`
# 2025-05-27 18:17:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_common_relationcurrent`
# 2025-05-27 18:17:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens97_processed_idsraw_gene_transcript`
# 2025-05-27 18:17:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens97_processed_idsraw_translation_transcript`
# 2025-05-27 18:18:02 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens97_common_relationcurrent`
# 2025-05-27 18:18:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens98_processed_idsraw_gene_transcript`
# 2025-05-27 18:18:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens98_processed_idsraw_translation_transcript`
# 2025-05-27 18:18:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens98_common_relationcurrent`
# 2025-05-27 18:18:25 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens99_processed_idsraw_gene_transcript`
# 2025-05-27 18:18:26 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens99_processed_idsraw_translation_transcript`
# 2025-05-27 18:18:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens99_common_relationcurrent`
# 2025-05-27 18:18:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens100_processed_idsraw_gene_transcript`
# 2025-05-27 18:18:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens100_processed_idsraw_translation_transcript`
# 2025-05-27 18:18:42 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens100_common_relationcurrent`
# 2025-05-27 18:18:51 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens101_processed_idsraw_gene_transcript`
# 2025-05-27 18:18:52 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens101_processed_idsraw_translation_transcript`
# 2025-05-27 18:18:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens101_common_relationcurrent`
# 2025-05-27 18:19:04 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens102_processed_idsraw_gene_transcript`
# 2025-05-27 18:19:06 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens102_processed_idsraw_translation_transcript`
# 2025-05-27 18:19:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens102_common_relationcurrent`
# 2025-05-27 18:19:18 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens103_processed_idsraw_gene_transcript`
# 2025-05-27 18:19:19 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens103_processed_idsraw_translation_transcript`
# 2025-05-27 18:19:22 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens103_common_relationcurrent`
# 2025-05-27 18:19:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens104_processed_idsraw_gene_transcript`
# 2025-05-27 18:19:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens104_processed_idsraw_translation_transcript`
# 2025-05-27 18:19:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens104_common_relationcurrent`
# 2025-05-27 18:19:45 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens105_processed_idsraw_gene_transcript`
# 2025-05-27 18:19:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens105_processed_idsraw_translation_transcript`
# 2025-05-27 18:19:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens105_common_relationcurrent`
# 2025-05-27 18:19:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens106_processed_idsraw_gene_transcript`
# 2025-05-27 18:20:01 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens106_processed_idsraw_translation_transcript`
# 2025-05-27 18:20:03 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens106_common_relationcurrent`
# 2025-05-27 18:20:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens107_processed_idsraw_gene_transcript`
# 2025-05-27 18:20:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens107_processed_idsraw_translation_transcript`
# 2025-05-27 18:20:17 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens107_common_relationcurrent`
# 2025-05-27 18:20:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens108_processed_idsraw_gene_transcript`
# 2025-05-27 18:20:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens108_processed_idsraw_translation_transcript`
# 2025-05-27 18:20:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens108_common_relationcurrent`
# 2025-05-27 18:20:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens109_processed_idsraw_gene_transcript`
# 2025-05-27 18:20:44 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens109_processed_idsraw_translation_transcript`
# 2025-05-27 18:20:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens109_common_relationcurrent`
# 2025-05-27 18:20:57 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens110_processed_idsraw_gene_transcript`
# 2025-05-27 18:20:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens110_processed_idsraw_translation_transcript`
# 2025-05-27 18:21:01 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens110_common_relationcurrent`
# 2025-05-27 18:21:11 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens111_processed_idsraw_gene_transcript`
# 2025-05-27 18:21:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens111_processed_idsraw_translation_transcript`
# 2025-05-27 18:21:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens111_common_relationcurrent`
# 2025-05-27 18:21:26 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens112_processed_idsraw_gene_transcript`
# 2025-05-27 18:21:27 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens112_processed_idsraw_translation_transcript`
# 2025-05-27 18:21:30 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens112_common_relationcurrent`
# 2025-05-27 18:21:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens113_processed_idsraw_gene_transcript`
# 2025-05-27 18:21:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens113_processed_idsraw_translation_transcript`
# 2025-05-27 18:21:44 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens113_common_relationcurrent`
# 2025-05-27 18:22:04 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_idsraw_gene_transcript`
# 2025-05-27 18:22:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_idsraw_translation_transcript`
# 2025-05-27 18:22:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_common_relationcurrent`
# 2025-05-27 18:22:25 INFO:graph_maker: Edges between external IDs to Ensembl IDs is being added for 'gene'.
# 2025-05-27 18:22:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_processed_external_relevant_gene`
# 2025-05-27 18:22:55 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens79_processed_external_relevant_gene`
# 2025-05-27 18:23:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_processed_external_relevant_gene`
# 2025-05-27 18:23:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens80_processed_external_relevant_gene`
# 2025-05-27 18:24:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_processed_external_relevant_gene`
# 2025-05-27 18:24:50 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens81_processed_external_relevant_gene`
# 2025-05-27 18:25:26 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_processed_external_relevant_gene`
# 2025-05-27 18:25:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens82_processed_external_relevant_gene`
# 2025-05-27 18:26:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_processed_external_relevant_gene`
# 2025-05-27 18:26:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens83_processed_external_relevant_gene`
# 2025-05-27 18:27:19 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_processed_external_relevant_gene`
# 2025-05-27 18:27:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens84_processed_external_relevant_gene`
# 2025-05-27 18:28:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_processed_external_relevant_gene`
# 2025-05-27 18:28:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens85_processed_external_relevant_gene`
# 2025-05-27 18:29:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_processed_external_relevant_gene`
# 2025-05-27 18:29:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens86_processed_external_relevant_gene`
# 2025-05-27 18:30:12 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_processed_external_relevant_gene`
# 2025-05-27 18:30:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens87_processed_external_relevant_gene`
# 2025-05-27 18:31:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_processed_external_relevant_gene`
# 2025-05-27 18:31:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens88_processed_external_relevant_gene`
# 2025-05-27 18:32:01 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_processed_external_relevant_gene`
# 2025-05-27 18:32:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens89_processed_external_relevant_gene`
# 2025-05-27 18:32:42 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_processed_external_relevant_gene`
# 2025-05-27 18:32:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens90_processed_external_relevant_gene`
# 2025-05-27 18:33:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_processed_external_relevant_gene`
# 2025-05-27 18:33:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens91_processed_external_relevant_gene`
# 2025-05-27 18:34:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_processed_external_relevant_gene`
# 2025-05-27 18:34:18 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens92_processed_external_relevant_gene`
# 2025-05-27 18:34:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_processed_external_relevant_gene`
# 2025-05-27 18:34:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens93_processed_external_relevant_gene`
# 2025-05-27 18:35:27 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_processed_external_relevant_gene`
# 2025-05-27 18:35:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens94_processed_external_relevant_gene`
# 2025-05-27 18:36:09 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_processed_external_relevant_gene`
# 2025-05-27 18:36:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens95_processed_external_relevant_gene`
# 2025-05-27 18:36:52 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_processed_external_relevant_gene`
# 2025-05-27 18:37:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens96_processed_external_relevant_gene`
# 2025-05-27 18:37:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens97_processed_external_relevant_gene`
# 2025-05-27 18:37:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens97_processed_external_relevant_gene`
# 2025-05-27 18:38:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens98_processed_external_relevant_gene`
# 2025-05-27 18:38:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens98_processed_external_relevant_gene`
# 2025-05-27 18:38:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens99_processed_external_relevant_gene`
# 2025-05-27 18:39:12 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens99_processed_external_relevant_gene`
# 2025-05-27 18:39:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens100_processed_external_relevant_gene`
# 2025-05-27 18:39:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens100_processed_external_relevant_gene`
# 2025-05-27 18:40:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens101_processed_external_relevant_gene`
# 2025-05-27 18:40:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens101_processed_external_relevant_gene`
# 2025-05-27 18:41:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens102_processed_external_relevant_gene`
# 2025-05-27 18:41:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens102_processed_external_relevant_gene`
# 2025-05-27 18:42:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens103_processed_external_relevant_gene`
# 2025-05-27 18:42:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens103_processed_external_relevant_gene`
# 2025-05-27 18:42:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens104_processed_external_relevant_gene`
# 2025-05-27 18:43:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens104_processed_external_relevant_gene`
# 2025-05-27 18:43:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens105_processed_external_relevant_gene`
# 2025-05-27 18:43:51 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens105_processed_external_relevant_gene`
# 2025-05-27 18:44:19 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens106_processed_external_relevant_gene`
# 2025-05-27 18:44:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens106_processed_external_relevant_gene`
# 2025-05-27 18:45:01 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens107_processed_external_relevant_gene`
# 2025-05-27 18:45:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens107_processed_external_relevant_gene`
# 2025-05-27 18:45:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens108_processed_external_relevant_gene`
# 2025-05-27 18:45:57 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens108_processed_external_relevant_gene`
# 2025-05-27 18:46:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens109_processed_external_relevant_gene`
# 2025-05-27 18:46:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens109_processed_external_relevant_gene`
# 2025-05-27 18:47:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens110_processed_external_relevant_gene`
# 2025-05-27 18:47:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens110_processed_external_relevant_gene`
# 2025-05-27 18:47:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens111_processed_external_relevant_gene`
# 2025-05-27 18:48:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens111_processed_external_relevant_gene`
# 2025-05-27 18:48:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens112_processed_external_relevant_gene`
# 2025-05-27 18:48:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens112_processed_external_relevant_gene`
# 2025-05-27 18:49:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens113_processed_external_relevant_gene`
# 2025-05-27 18:49:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens113_processed_external_relevant_gene`
# 2025-05-27 18:50:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_external_relevant_gene`
# 2025-05-27 18:50:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens114_processed_external_relevant_gene`
# 2025-05-27 18:50:48 WARNING:graph_maker: New nodes added as assembly nodes: 29401
# 2025-05-27 18:50:48 INFO:graph_maker: Edges between external IDs to Ensembl IDs is being added for 'transcript'.
# 2025-05-27 18:51:03 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_processed_external_relevant_transcript`
# 2025-05-27 18:51:25 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens79_processed_external_relevant_transcript`
# 2025-05-27 18:52:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_processed_external_relevant_transcript`
# 2025-05-27 18:52:45 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens80_processed_external_relevant_transcript`
# 2025-05-27 18:53:19 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_processed_external_relevant_transcript`
# 2025-05-27 18:53:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens81_processed_external_relevant_transcript`
# 2025-05-27 18:54:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_processed_external_relevant_transcript`
# 2025-05-27 18:54:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens82_processed_external_relevant_transcript`
# 2025-05-27 18:55:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_processed_external_relevant_transcript`
# 2025-05-27 18:55:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens83_processed_external_relevant_transcript`
# 2025-05-27 18:56:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_processed_external_relevant_transcript`
# 2025-05-27 18:56:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens84_processed_external_relevant_transcript`
# 2025-05-27 18:57:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_processed_external_relevant_transcript`
# 2025-05-27 18:57:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens85_processed_external_relevant_transcript`
# 2025-05-27 18:58:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_processed_external_relevant_transcript`
# 2025-05-27 18:58:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens86_processed_external_relevant_transcript`
# 2025-05-27 18:59:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_processed_external_relevant_transcript`
# 2025-05-27 18:59:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens87_processed_external_relevant_transcript`
# 2025-05-27 19:00:17 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_processed_external_relevant_transcript`
# 2025-05-27 19:00:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens88_processed_external_relevant_transcript`
# 2025-05-27 19:01:20 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_processed_external_relevant_transcript`
# 2025-05-27 19:01:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens89_processed_external_relevant_transcript`
# 2025-05-27 19:02:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_processed_external_relevant_transcript`
# 2025-05-27 19:02:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens90_processed_external_relevant_transcript`
# 2025-05-27 19:03:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_processed_external_relevant_transcript`
# 2025-05-27 19:03:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens91_processed_external_relevant_transcript`
# 2025-05-27 19:04:03 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_processed_external_relevant_transcript`
# 2025-05-27 19:04:22 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens92_processed_external_relevant_transcript`
# 2025-05-27 19:04:57 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_processed_external_relevant_transcript`
# 2025-05-27 19:05:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens93_processed_external_relevant_transcript`
# 2025-05-27 19:05:51 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_processed_external_relevant_transcript`
# 2025-05-27 19:06:11 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens94_processed_external_relevant_transcript`
# 2025-05-27 19:06:45 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_processed_external_relevant_transcript`
# 2025-05-27 19:07:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens95_processed_external_relevant_transcript`
# 2025-05-27 19:07:42 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_processed_external_relevant_transcript`
# 2025-05-27 19:08:01 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens96_processed_external_relevant_transcript`
# 2025-05-27 19:08:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens97_processed_external_relevant_transcript`
# 2025-05-27 19:08:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens97_processed_external_relevant_transcript`
# 2025-05-27 19:09:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens98_processed_external_relevant_transcript`
# 2025-05-27 19:09:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens98_processed_external_relevant_transcript`
# 2025-05-27 19:10:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens99_processed_external_relevant_transcript`
# 2025-05-27 19:10:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens99_processed_external_relevant_transcript`
# 2025-05-27 19:11:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens100_processed_external_relevant_transcript`
# 2025-05-27 19:11:52 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens100_processed_external_relevant_transcript`
# 2025-05-27 19:12:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens101_processed_external_relevant_transcript`
# 2025-05-27 19:12:53 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens101_processed_external_relevant_transcript`
# 2025-05-27 19:13:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens102_processed_external_relevant_transcript`
# 2025-05-27 19:13:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens102_processed_external_relevant_transcript`
# 2025-05-27 19:14:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens103_processed_external_relevant_transcript`
# 2025-05-27 19:14:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens103_processed_external_relevant_transcript`
# 2025-05-27 19:15:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens104_processed_external_relevant_transcript`
# 2025-05-27 19:16:00 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens104_processed_external_relevant_transcript`
# 2025-05-27 19:16:42 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens105_processed_external_relevant_transcript`
# 2025-05-27 19:17:03 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens105_processed_external_relevant_transcript`
# 2025-05-27 19:17:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens106_processed_external_relevant_transcript`
# 2025-05-27 19:18:06 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens106_processed_external_relevant_transcript`
# 2025-05-27 19:18:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens107_processed_external_relevant_transcript`
# 2025-05-27 19:19:11 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens107_processed_external_relevant_transcript`
# 2025-05-27 19:19:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens108_processed_external_relevant_transcript`
# 2025-05-27 19:20:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens108_processed_external_relevant_transcript`
# 2025-05-27 19:21:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens109_processed_external_relevant_transcript`
# 2025-05-27 19:22:00 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens109_processed_external_relevant_transcript`
# 2025-05-27 19:22:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens110_processed_external_relevant_transcript`
# 2025-05-27 19:23:02 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens110_processed_external_relevant_transcript`
# 2025-05-27 19:23:45 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens111_processed_external_relevant_transcript`
# 2025-05-27 19:24:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens111_processed_external_relevant_transcript`
# 2025-05-27 19:24:50 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens112_processed_external_relevant_transcript`
# 2025-05-27 19:25:09 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens112_processed_external_relevant_transcript`
# 2025-05-27 19:25:55 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens113_processed_external_relevant_transcript`
# 2025-05-27 19:26:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens113_processed_external_relevant_transcript`
# 2025-05-27 19:27:01 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_external_relevant_transcript`
# 2025-05-27 19:27:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens114_processed_external_relevant_transcript`
# 2025-05-27 19:27:43 WARNING:graph_maker: New nodes added as assembly nodes: 104892
# 2025-05-27 19:27:43 INFO:graph_maker: Edges between external IDs to Ensembl IDs is being added for 'translation'.
# 2025-05-27 19:28:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_processed_external_relevant_translation`
# 2025-05-27 19:28:57 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens79_processed_external_relevant_translation`
# 2025-05-27 19:29:48 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_processed_external_relevant_translation`
# 2025-05-27 19:30:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens80_processed_external_relevant_translation`
# 2025-05-27 19:31:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_processed_external_relevant_translation`
# 2025-05-27 19:31:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens81_processed_external_relevant_translation`
# 2025-05-27 19:32:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_processed_external_relevant_translation`
# 2025-05-27 19:33:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens82_processed_external_relevant_translation`
# 2025-05-27 19:34:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_processed_external_relevant_translation`
# 2025-05-27 19:34:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens83_processed_external_relevant_translation`
# 2025-05-27 19:35:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_processed_external_relevant_translation`
# 2025-05-27 19:36:19 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens84_processed_external_relevant_translation`
# 2025-05-27 19:37:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_processed_external_relevant_translation`
# 2025-05-27 19:37:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens85_processed_external_relevant_translation`
# 2025-05-27 19:38:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_processed_external_relevant_translation`
# 2025-05-27 19:39:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens86_processed_external_relevant_translation`
# 2025-05-27 19:40:04 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_processed_external_relevant_translation`
# 2025-05-27 19:40:44 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens87_processed_external_relevant_translation`
# 2025-05-27 19:41:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_processed_external_relevant_translation`
# 2025-05-27 19:42:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens88_processed_external_relevant_translation`
# 2025-05-27 19:42:52 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_processed_external_relevant_translation`
# 2025-05-27 19:43:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens89_processed_external_relevant_translation`
# 2025-05-27 19:44:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_processed_external_relevant_translation`
# ...
# 2025-05-27 20:24:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens89_processed_idsraw_translation_gene`
# 2025-05-27 20:24:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens89_common_relationcurrent`
# 2025-05-27 20:24:48 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens88_processed_idsraw_transcript_gene`
# 2025-05-27 20:24:51 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens88_processed_idsraw_translation_gene`
# 2025-05-27 20:24:53 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens88_common_relationcurrent`
# 2025-05-27 20:25:02 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens87_processed_idsraw_transcript_gene`
# 2025-05-27 20:25:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens87_processed_idsraw_translation_gene`
# 2025-05-27 20:25:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens87_common_relationcurrent`
# 2025-05-27 20:25:17 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens86_processed_idsraw_transcript_gene`
# 2025-05-27 20:25:20 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens86_processed_idsraw_translation_gene`
# 2025-05-27 20:25:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens86_common_relationcurrent`
# 2025-05-27 20:25:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens85_processed_idsraw_transcript_gene`
# 2025-05-27 20:25:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens85_processed_idsraw_translation_gene`
# 2025-05-27 20:25:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens85_common_relationcurrent`
# 2025-05-27 20:25:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens84_processed_idsraw_transcript_gene`
# 2025-05-27 20:25:51 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens84_processed_idsraw_translation_gene`
# 2025-05-27 20:25:53 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens84_common_relationcurrent`
# 2025-05-27 20:26:03 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens83_processed_idsraw_transcript_gene`
# 2025-05-27 20:26:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens83_processed_idsraw_translation_gene`
# 2025-05-27 20:26:09 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens83_common_relationcurrent`
# 2025-05-27 20:26:19 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens82_processed_idsraw_transcript_gene`
# 2025-05-27 20:26:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens82_processed_idsraw_translation_gene`
# 2025-05-27 20:26:25 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens82_common_relationcurrent`
# 2025-05-27 20:26:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens81_processed_idsraw_transcript_gene`
# 2025-05-27 20:26:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens81_processed_idsraw_translation_gene`
# 2025-05-27 20:26:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens81_common_relationcurrent`
# 2025-05-27 20:26:51 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens80_processed_idsraw_transcript_gene`
# 2025-05-27 20:26:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens80_processed_idsraw_translation_gene`
# 2025-05-27 20:26:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens80_common_relationcurrent`
# 2025-05-27 20:27:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens79_processed_idsraw_transcript_gene`
# 2025-05-27 20:27:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens79_processed_idsraw_translation_gene`
# 2025-05-27 20:27:12 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens79_common_relationcurrent`
# 2025-05-27 20:27:22 WARNING:graph_maker: New edges are added between assembly Ensembl nodes: 255026
# 2025-05-27 20:27:22 INFO:graph_maker: Versionless Ensembl IDs are being connected.
# 2025-05-27 20:27:22 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens79_processed_ids_gene`
# 2025-05-27 20:27:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens80_processed_ids_gene`
# 2025-05-27 20:27:26 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens81_processed_ids_gene`
# 2025-05-27 20:27:27 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens82_processed_ids_gene`
# 2025-05-27 20:27:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens83_processed_ids_gene`
# 2025-05-27 20:27:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens84_processed_ids_gene`
# 2025-05-27 20:27:30 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens85_processed_ids_gene`
# 2025-05-27 20:27:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens86_processed_ids_gene`
# 2025-05-27 20:27:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens87_processed_ids_gene`
# 2025-05-27 20:27:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens88_processed_ids_gene`
# 2025-05-27 20:27:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens89_processed_ids_gene`
# 2025-05-27 20:27:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens90_processed_ids_gene`
# 2025-05-27 20:27:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens91_processed_ids_gene`
# 2025-05-27 20:27:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens92_processed_ids_gene`
# 2025-05-27 20:27:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens93_processed_ids_gene`
# 2025-05-27 20:27:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens94_processed_ids_gene`
# 2025-05-27 20:27:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens95_processed_ids_gene`
# 2025-05-27 20:27:42 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens96_processed_ids_gene`
# 2025-05-27 20:27:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens97_processed_ids_gene`
# 2025-05-27 20:27:45 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens98_processed_ids_gene`
# 2025-05-27 20:27:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens99_processed_ids_gene`
# 2025-05-27 20:27:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens100_processed_ids_gene`
# 2025-05-27 20:27:48 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens101_processed_ids_gene`
# 2025-05-27 20:27:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens102_processed_ids_gene`
# 2025-05-27 20:27:50 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens103_processed_ids_gene`
# 2025-05-27 20:27:51 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens104_processed_ids_gene`
# 2025-05-27 20:27:52 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens105_processed_ids_gene`
# 2025-05-27 20:27:53 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens106_processed_ids_gene`
# 2025-05-27 20:27:54 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens107_processed_ids_gene`
# 2025-05-27 20:27:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens108_processed_ids_gene`
# 2025-05-27 20:27:57 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens109_processed_ids_gene`
# 2025-05-27 20:27:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens110_processed_ids_gene`
# 2025-05-27 20:27:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens111_processed_ids_gene`
# 2025-05-27 20:28:00 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens112_processed_ids_gene`
# 2025-05-27 20:28:01 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens113_processed_ids_gene`
# 2025-05-27 20:28:02 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens114_processed_ids_gene`
# 2025-05-27 20:28:03 INFO:graph_maker: Edges between versionless ID to version ID has been added for 'gene', assembly 37.
# 2025-05-27 20:28:03 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_processed_ids_gene`
# 2025-05-27 20:28:04 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_processed_ids_gene`
# 2025-05-27 20:28:06 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_processed_ids_gene`
# 2025-05-27 20:28:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_processed_ids_gene`
# 2025-05-27 20:28:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_processed_ids_gene`
# 2025-05-27 20:28:09 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_processed_ids_gene`
# 2025-05-27 20:28:11 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_processed_ids_gene`
# 2025-05-27 20:28:12 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_processed_ids_gene`
# 2025-05-27 20:28:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_processed_ids_gene`
# 2025-05-27 20:28:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_processed_ids_gene`
# 2025-05-27 20:28:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_processed_ids_gene`
# 2025-05-27 20:28:17 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_processed_ids_gene`
# 2025-05-27 20:28:18 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_processed_ids_gene`
# 2025-05-27 20:28:19 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_processed_ids_gene`
# 2025-05-27 20:28:21 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_processed_ids_gene`
# 2025-05-27 20:28:22 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_processed_ids_gene`
# 2025-05-27 20:28:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_processed_ids_gene`
# 2025-05-27 20:28:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_processed_ids_gene`
# 2025-05-27 20:28:25 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens97_processed_ids_gene`
# 2025-05-27 20:28:27 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens98_processed_ids_gene`
# 2025-05-27 20:28:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens99_processed_ids_gene`
# 2025-05-27 20:28:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens100_processed_ids_gene`
# 2025-05-27 20:28:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens101_processed_ids_gene`
# 2025-05-27 20:28:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens102_processed_ids_gene`
# 2025-05-27 20:28:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens103_processed_ids_gene`
# 2025-05-27 20:28:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens104_processed_ids_gene`
# 2025-05-27 20:28:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens105_processed_ids_gene`
# 2025-05-27 20:28:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens106_processed_ids_gene`
# 2025-05-27 20:28:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens107_processed_ids_gene`
# 2025-05-27 20:28:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens108_processed_ids_gene`
# 2025-05-27 20:28:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens109_processed_ids_gene`
# 2025-05-27 20:28:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens110_processed_ids_gene`
# 2025-05-27 20:28:44 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens111_processed_ids_gene`
# 2025-05-27 20:28:45 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens112_processed_ids_gene`
# 2025-05-27 20:28:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens113_processed_ids_gene`
# 2025-05-27 20:28:48 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_processed_ids_gene`
# 2025-05-27 20:28:49 INFO:graph_maker: Edges between versionless ID to version ID has been added for 'gene', assembly 38.
# 2025-05-27 20:28:49 INFO:graph_maker: Synonymous external nodes are being merged into one.
# 2025-05-27 20:28:52 INFO:graph_maker: Number of removed nodes in the process of merging synonymous nodes: 12304
# 2025-05-27 20:29:46 INFO:graph_maker: The graph is being exported as '/Users/kemalinecik/Downloads/idtrack_temp/graph_homo_sapiens_min79_max114_narrow.pickle'.
# CPU times: user 2h 4min 52s, sys: 10min 26s, total: 2h 15min 19s
# Wall time: 2h 22min 2s
