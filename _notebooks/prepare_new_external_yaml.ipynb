# %% [markdown]
# # External Database Description Initialization

# %%
import sys
sys.path.append("/Users/kemalinecik/git_nosync/idtrack")

import os
import time
import pickle
import idtrack
import copy

# %% [markdown]
# Initialize the idtrack API first

# %%
local_dir = "/Users/kemalinecik/Downloads/idtrack_temp"
idt = idtrack.API(local_repository=local_dir)
idt.configure_logger()

# %% [markdown]
# Let's initialize idtrack for 'human'

# %%
organism_formal_name, last_ensembl_release = idt.get_ensembl_organism("homo sapiens")
organism_formal_name, last_ensembl_release
# Out:
# 2025-05-27 10:48:56 INFO:verify_organism: Ensembl Rest API query to get the organism names and associated releases.
# ('homo_sapiens', 114)

# %%
dm = idt.get_database_manager(organism_name='homo_sapiens', last_ensembl_release=114)
# Out:
# 2025-05-27 10:48:58 INFO:database_manager: Available MySQL databases for homo_sapiens in 38 assembly and 0 release is being fetched.
# 2025-05-27 10:48:59 INFO:database_manager: Available MySQL databases for homo_sapiens in 38 assembly and 114 release is being fetched.
# 2025-05-27 10:49:00 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens114_common_availabledatabases`

# %% [markdown]
# ```python
# dm = idtrack.DatabaseManager(
#     organism='homo_sapiens',
#     ensembl_release=None,
#     ignore_before=90,
#     ignore_after=95,
#     form=copy.deepcopy(idtrack.DB.backbone_form),
#     local_repository=local_dir,
# )
# ```

# %%
# %%time
_ = dm.create_database_content(just_download=True)
# Out:
# 2025-05-27 10:49:08 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `79`
# 2025-05-27 10:49:09 INFO:database_manager: Raw table for `gene` on ensembl release `79` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 10:49:09 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 10:49:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_processed_idsraw_gene_gene`
# 2025-05-27 10:50:16 INFO:database_manager: Raw table for `object_xref` on ensembl release `79` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 10:50:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 10:52:35 INFO:database_manager: Raw table for `xref` on ensembl release `79` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 10:52:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 10:53:35 INFO:database_manager: Raw table for `external_db` on ensembl release `79` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 10:53:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 10:53:37 INFO:database_manager: Raw table for `identity_xref` on ensembl release `79` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 10:53:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 10:53:41 INFO:database_manager: Raw table for `external_synonym` on ensembl release `79` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 10:53:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 10:53:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens79_processed_external_database_gene`
# 2025-05-27 10:53:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `80`
# 2025-05-27 10:53:51 INFO:database_manager: Raw table for `gene` on ensembl release `80` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 10:53:51 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 10:53:52 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_processed_idsraw_gene_gene`
# 2025-05-27 10:55:10 INFO:database_manager: Raw table for `object_xref` on ensembl release `80` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 10:55:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 10:57:27 INFO:database_manager: Raw table for `xref` on ensembl release `80` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 10:57:27 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 10:58:32 INFO:database_manager: Raw table for `external_db` on ensembl release `80` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 10:58:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 10:58:35 INFO:database_manager: Raw table for `identity_xref` on ensembl release `80` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 10:58:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 10:58:38 INFO:database_manager: Raw table for `external_synonym` on ensembl release `80` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 10:58:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 10:58:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens80_processed_external_database_gene`
# 2025-05-27 10:58:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `81`
# 2025-05-27 10:58:49 INFO:database_manager: Raw table for `gene` on ensembl release `81` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 10:58:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 10:58:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_processed_idsraw_gene_gene`
# 2025-05-27 10:59:44 INFO:database_manager: Raw table for `object_xref` on ensembl release `81` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 10:59:44 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:02:02 INFO:database_manager: Raw table for `xref` on ensembl release `81` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:02:02 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:03:08 INFO:database_manager: Raw table for `external_db` on ensembl release `81` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:03:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:03:10 INFO:database_manager: Raw table for `identity_xref` on ensembl release `81` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:03:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:03:14 INFO:database_manager: Raw table for `external_synonym` on ensembl release `81` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:03:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:03:21 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens81_processed_external_database_gene`
# 2025-05-27 11:03:21 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `82`
# 2025-05-27 11:03:23 INFO:database_manager: Raw table for `gene` on ensembl release `82` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:03:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:03:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_processed_idsraw_gene_gene`
# 2025-05-27 11:04:50 INFO:database_manager: Raw table for `object_xref` on ensembl release `82` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:04:50 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:07:12 INFO:database_manager: Raw table for `xref` on ensembl release `82` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:07:12 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:08:20 INFO:database_manager: Raw table for `external_db` on ensembl release `82` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:08:20 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:08:23 INFO:database_manager: Raw table for `identity_xref` on ensembl release `82` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:08:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:08:25 INFO:database_manager: Raw table for `external_synonym` on ensembl release `82` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:08:25 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:08:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens82_processed_external_database_gene`
# 2025-05-27 11:08:33 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `83`
# 2025-05-27 11:08:34 INFO:database_manager: Raw table for `gene` on ensembl release `83` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:08:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:08:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_processed_idsraw_gene_gene`
# 2025-05-27 11:09:37 INFO:database_manager: Raw table for `object_xref` on ensembl release `83` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:09:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:11:59 INFO:database_manager: Raw table for `xref` on ensembl release `83` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:11:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:13:11 INFO:database_manager: Raw table for `external_db` on ensembl release `83` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:13:11 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:13:13 INFO:database_manager: Raw table for `identity_xref` on ensembl release `83` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:13:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:13:16 INFO:database_manager: Raw table for `external_synonym` on ensembl release `83` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:13:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:13:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens83_processed_external_database_gene`
# 2025-05-27 11:13:24 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `84`
# 2025-05-27 11:13:25 INFO:database_manager: Raw table for `gene` on ensembl release `84` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:13:25 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:13:26 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_processed_idsraw_gene_gene`
# 2025-05-27 11:14:30 INFO:database_manager: Raw table for `object_xref` on ensembl release `84` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:14:30 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:16:32 INFO:database_manager: Raw table for `xref` on ensembl release `84` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:16:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:17:43 INFO:database_manager: Raw table for `external_db` on ensembl release `84` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:17:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:17:45 INFO:database_manager: Raw table for `identity_xref` on ensembl release `84` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:17:45 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:17:48 INFO:database_manager: Raw table for `external_synonym` on ensembl release `84` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:17:48 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:17:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens84_processed_external_database_gene`
# 2025-05-27 11:17:56 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `85`
# 2025-05-27 11:17:57 INFO:database_manager: Raw table for `gene` on ensembl release `85` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:17:57 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:17:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_processed_idsraw_gene_gene`
# 2025-05-27 11:18:47 INFO:database_manager: Raw table for `object_xref` on ensembl release `85` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:18:48 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:21:02 INFO:database_manager: Raw table for `xref` on ensembl release `85` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:21:02 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:22:24 INFO:database_manager: Raw table for `external_db` on ensembl release `85` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:22:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:22:26 INFO:database_manager: Raw table for `identity_xref` on ensembl release `85` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:22:26 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:22:29 INFO:database_manager: Raw table for `external_synonym` on ensembl release `85` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:22:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:22:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens85_processed_external_database_gene`
# 2025-05-27 11:22:37 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `86`
# 2025-05-27 11:22:38 INFO:database_manager: Raw table for `gene` on ensembl release `86` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:22:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:22:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_processed_idsraw_gene_gene`
# 2025-05-27 11:23:58 INFO:database_manager: Raw table for `object_xref` on ensembl release `86` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:23:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:25:56 INFO:database_manager: Raw table for `xref` on ensembl release `86` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:25:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:27:10 INFO:database_manager: Raw table for `external_db` on ensembl release `86` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:27:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:27:11 INFO:database_manager: Raw table for `identity_xref` on ensembl release `86` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:27:11 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:27:14 INFO:database_manager: Raw table for `external_synonym` on ensembl release `86` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:27:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:27:22 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens86_processed_external_database_gene`
# 2025-05-27 11:27:22 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `87`
# 2025-05-27 11:27:23 INFO:database_manager: Raw table for `gene` on ensembl release `87` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:27:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:27:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_processed_idsraw_gene_gene`
# 2025-05-27 11:28:37 INFO:database_manager: Raw table for `object_xref` on ensembl release `87` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:28:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:31:20 INFO:database_manager: Raw table for `xref` on ensembl release `87` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:31:20 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:32:35 INFO:database_manager: Raw table for `external_db` on ensembl release `87` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:32:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:32:37 INFO:database_manager: Raw table for `identity_xref` on ensembl release `87` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:32:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:32:40 INFO:database_manager: Raw table for `external_synonym` on ensembl release `87` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:32:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:32:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens87_processed_external_database_gene`
# 2025-05-27 11:32:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `88`
# 2025-05-27 11:32:50 INFO:database_manager: Raw table for `gene` on ensembl release `88` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:32:50 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:32:51 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_processed_idsraw_gene_gene`
# 2025-05-27 11:33:47 INFO:database_manager: Raw table for `object_xref` on ensembl release `88` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:33:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:36:05 INFO:database_manager: Raw table for `xref` on ensembl release `88` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:36:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:37:20 INFO:database_manager: Raw table for `external_db` on ensembl release `88` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:37:20 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:37:22 INFO:database_manager: Raw table for `identity_xref` on ensembl release `88` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:37:22 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:37:24 INFO:database_manager: Raw table for `external_synonym` on ensembl release `88` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:37:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:37:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens88_processed_external_database_gene`
# 2025-05-27 11:37:31 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `89`
# 2025-05-27 11:37:32 INFO:database_manager: Raw table for `gene` on ensembl release `89` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:37:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:37:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_processed_idsraw_gene_gene`
# 2025-05-27 11:38:20 INFO:database_manager: Raw table for `object_xref` on ensembl release `89` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:38:20 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:40:14 INFO:database_manager: Raw table for `xref` on ensembl release `89` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:40:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:41:05 INFO:database_manager: Raw table for `external_db` on ensembl release `89` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:41:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:41:07 INFO:database_manager: Raw table for `identity_xref` on ensembl release `89` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:41:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:41:10 INFO:database_manager: Raw table for `external_synonym` on ensembl release `89` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:41:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:41:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens89_processed_external_database_gene`
# 2025-05-27 11:41:15 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `90`
# 2025-05-27 11:41:16 INFO:database_manager: Raw table for `gene` on ensembl release `90` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:41:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:41:17 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_processed_idsraw_gene_gene`
# 2025-05-27 11:42:36 INFO:database_manager: Raw table for `object_xref` on ensembl release `90` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:42:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:44:32 INFO:database_manager: Raw table for `xref` on ensembl release `90` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:44:32 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:45:24 INFO:database_manager: Raw table for `external_db` on ensembl release `90` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:45:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:45:26 INFO:database_manager: Raw table for `identity_xref` on ensembl release `90` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:45:26 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:45:29 INFO:database_manager: Raw table for `external_synonym` on ensembl release `90` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:45:29 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:45:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens90_processed_external_database_gene`
# 2025-05-27 11:45:34 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `91`
# 2025-05-27 11:45:35 INFO:database_manager: Raw table for `gene` on ensembl release `91` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:45:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:45:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_processed_idsraw_gene_gene`
# 2025-05-27 11:46:38 INFO:database_manager: Raw table for `object_xref` on ensembl release `91` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:46:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:48:39 INFO:database_manager: Raw table for `xref` on ensembl release `91` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:48:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:49:31 INFO:database_manager: Raw table for `external_db` on ensembl release `91` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:49:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:49:35 INFO:database_manager: Raw table for `identity_xref` on ensembl release `91` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:49:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:49:38 INFO:database_manager: Raw table for `external_synonym` on ensembl release `91` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:49:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:49:44 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens91_processed_external_database_gene`
# 2025-05-27 11:49:44 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `92`
# 2025-05-27 11:49:45 INFO:database_manager: Raw table for `gene` on ensembl release `92` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:49:45 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:49:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_processed_idsraw_gene_gene`
# 2025-05-27 11:51:12 INFO:database_manager: Raw table for `object_xref` on ensembl release `92` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:51:12 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:52:49 INFO:database_manager: Raw table for `xref` on ensembl release `92` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:52:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:53:38 INFO:database_manager: Raw table for `external_db` on ensembl release `92` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:53:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:53:40 INFO:database_manager: Raw table for `identity_xref` on ensembl release `92` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:53:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:53:43 INFO:database_manager: Raw table for `external_synonym` on ensembl release `92` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:53:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:53:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens92_processed_external_database_gene`
# 2025-05-27 11:53:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `93`
# 2025-05-27 11:53:48 INFO:database_manager: Raw table for `gene` on ensembl release `93` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:53:48 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:53:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_processed_idsraw_gene_gene`
# 2025-05-27 11:55:11 INFO:database_manager: Raw table for `object_xref` on ensembl release `93` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:55:12 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 11:56:46 INFO:database_manager: Raw table for `xref` on ensembl release `93` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 11:56:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 11:57:37 INFO:database_manager: Raw table for `external_db` on ensembl release `93` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 11:57:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 11:57:39 INFO:database_manager: Raw table for `identity_xref` on ensembl release `93` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 11:57:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 11:57:41 INFO:database_manager: Raw table for `external_synonym` on ensembl release `93` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 11:57:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 11:57:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens93_processed_external_database_gene`
# 2025-05-27 11:57:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `94`
# 2025-05-27 11:57:47 INFO:database_manager: Raw table for `gene` on ensembl release `94` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 11:57:47 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 11:57:48 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_processed_idsraw_gene_gene`
# 2025-05-27 11:59:07 INFO:database_manager: Raw table for `object_xref` on ensembl release `94` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 11:59:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 12:01:07 INFO:database_manager: Raw table for `xref` on ensembl release `94` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 12:01:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 12:01:56 INFO:database_manager: Raw table for `external_db` on ensembl release `94` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 12:01:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 12:01:58 INFO:database_manager: Raw table for `identity_xref` on ensembl release `94` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 12:01:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 12:02:01 INFO:database_manager: Raw table for `external_synonym` on ensembl release `94` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 12:02:01 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 12:02:06 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens94_processed_external_database_gene`
# 2025-05-27 12:02:06 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `95`
# 2025-05-27 12:02:07 INFO:database_manager: Raw table for `gene` on ensembl release `95` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 12:02:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 12:02:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_processed_idsraw_gene_gene`
# 2025-05-27 12:02:40 INFO:database_manager: Raw table for `object_xref` on ensembl release `95` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 12:02:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 12:05:11 INFO:database_manager: Raw table for `xref` on ensembl release `95` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 12:05:11 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 12:06:02 INFO:database_manager: Raw table for `external_db` on ensembl release `95` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 12:06:02 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 12:06:07 INFO:database_manager: Raw table for `identity_xref` on ensembl release `95` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 12:06:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 12:06:10 INFO:database_manager: Raw table for `external_synonym` on ensembl release `95` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 12:06:10 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 12:06:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens95_processed_external_database_gene`
# 2025-05-27 12:06:16 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `96`
# 2025-05-27 12:06:19 INFO:database_manager: Raw table for `gene` on ensembl release `96` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 12:06:19 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# 2025-05-27 12:06:20 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_processed_idsraw_gene_gene`
# 2025-05-27 12:07:58 INFO:database_manager: Raw table for `object_xref` on ensembl release `96` was downloaded for following columns: ensembl_id, ensembl_object_type, xref_id, object_xref_id.
# 2025-05-27 12:07:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_mysql_object_xref_COL_ensembl_id_COL_ensembl_object_type_COL_object_xref_id_COL_xref_id`
# 2025-05-27 12:10:30 INFO:database_manager: Raw table for `xref` on ensembl release `96` was downloaded for following columns: xref_id, external_db_id, dbprimary_acc, display_label.
# 2025-05-27 12:10:30 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_mysql_xref_COL_dbprimary_acc_COL_display_label_COL_external_db_id_COL_xref_id`
# 2025-05-27 12:11:22 INFO:database_manager: Raw table for `external_db` on ensembl release `96` was downloaded for following columns: external_db_id, db_name, db_display_name.
# 2025-05-27 12:11:22 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_mysql_external_db_COL_db_display_name_COL_db_name_COL_external_db_id`
# 2025-05-27 12:11:28 INFO:database_manager: Raw table for `identity_xref` on ensembl release `96` was downloaded for following columns: ensembl_identity, xref_identity, object_xref_id.
# 2025-05-27 12:11:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_mysql_identity_xref_COL_ensembl_identity_COL_object_xref_id_COL_xref_identity`
# 2025-05-27 12:11:31 INFO:database_manager: Raw table for `external_synonym` on ensembl release `96` was downloaded for following columns: xref_id, synonym.
# 2025-05-27 12:11:31 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_mysql_external_synonym_COL_synonym_COL_xref_id`
# 2025-05-27 12:11:36 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens96_processed_external_database_gene`
# 2025-05-27 12:11:36 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `97`
# 2025-05-27 12:11:38 INFO:database_manager: Raw table for `gene` on ensembl release `97` was downloaded for following columns: gene_id, stable_id, version.
# 2025-05-27 12:11:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-38.h5` with key `ens97_mysql_gene_COL_gene_id_COL_stable_id_COL_version`
# ...
# 2025-05-27 17:16:09 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens96_processed_external_database_translation`
# 2025-05-27 17:16:09 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `97`
# 2025-05-27 17:16:11 INFO:database_manager: Raw table for `translation` on ensembl release `97` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:16:11 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens97_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:16:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens97_processed_idsraw_translation_translation`
# 2025-05-27 17:16:44 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens97_processed_external_database_translation`
# 2025-05-27 17:16:44 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `98`
# 2025-05-27 17:16:49 INFO:database_manager: Raw table for `translation` on ensembl release `98` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:16:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens98_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:16:50 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens98_processed_idsraw_translation_translation`
# 2025-05-27 17:17:21 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens98_processed_external_database_translation`
# 2025-05-27 17:17:21 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `99`
# 2025-05-27 17:17:26 INFO:database_manager: Raw table for `translation` on ensembl release `99` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:17:26 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens99_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:17:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens99_processed_idsraw_translation_translation`
# 2025-05-27 17:17:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens99_processed_external_database_translation`
# 2025-05-27 17:17:59 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `100`
# 2025-05-27 17:18:03 INFO:database_manager: Raw table for `translation` on ensembl release `100` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:18:03 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens100_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:18:04 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens100_processed_idsraw_translation_translation`
# 2025-05-27 17:18:35 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens100_processed_external_database_translation`
# 2025-05-27 17:18:35 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `101`
# 2025-05-27 17:18:38 INFO:database_manager: Raw table for `translation` on ensembl release `101` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:18:38 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens101_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:18:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens101_processed_idsraw_translation_translation`
# 2025-05-27 17:19:11 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens101_processed_external_database_translation`
# 2025-05-27 17:19:11 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `102`
# 2025-05-27 17:19:13 INFO:database_manager: Raw table for `translation` on ensembl release `102` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:19:13 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens102_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:19:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens102_processed_idsraw_translation_translation`
# 2025-05-27 17:19:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens102_processed_external_database_translation`
# 2025-05-27 17:19:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `103`
# 2025-05-27 17:19:48 INFO:database_manager: Raw table for `translation` on ensembl release `103` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:19:48 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens103_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:19:50 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens103_processed_idsraw_translation_translation`
# 2025-05-27 17:20:21 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens103_processed_external_database_translation`
# 2025-05-27 17:20:21 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `104`
# 2025-05-27 17:20:23 INFO:database_manager: Raw table for `translation` on ensembl release `104` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:20:23 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens104_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:20:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens104_processed_idsraw_translation_translation`
# 2025-05-27 17:20:56 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens104_processed_external_database_translation`
# 2025-05-27 17:20:56 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `105`
# 2025-05-27 17:20:58 INFO:database_manager: Raw table for `translation` on ensembl release `105` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:20:58 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens105_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:20:59 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens105_processed_idsraw_translation_translation`
# 2025-05-27 17:21:30 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens105_processed_external_database_translation`
# 2025-05-27 17:21:30 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `106`
# 2025-05-27 17:21:33 INFO:database_manager: Raw table for `translation` on ensembl release `106` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:21:33 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens106_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:21:34 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens106_processed_idsraw_translation_translation`
# 2025-05-27 17:22:05 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens106_processed_external_database_translation`
# 2025-05-27 17:22:05 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `107`
# 2025-05-27 17:22:07 INFO:database_manager: Raw table for `translation` on ensembl release `107` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:22:07 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens107_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:22:08 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens107_processed_idsraw_translation_translation`
# 2025-05-27 17:22:39 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens107_processed_external_database_translation`
# 2025-05-27 17:22:39 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `108`
# 2025-05-27 17:22:41 INFO:database_manager: Raw table for `translation` on ensembl release `108` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:22:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens108_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:22:43 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens108_processed_idsraw_translation_translation`
# 2025-05-27 17:23:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens108_processed_external_database_translation`
# 2025-05-27 17:23:14 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `109`
# 2025-05-27 17:23:16 INFO:database_manager: Raw table for `translation` on ensembl release `109` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:23:16 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens109_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:23:18 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens109_processed_idsraw_translation_translation`
# 2025-05-27 17:23:49 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens109_processed_external_database_translation`
# 2025-05-27 17:23:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `110`
# 2025-05-27 17:23:52 INFO:database_manager: Raw table for `translation` on ensembl release `110` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:23:52 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens110_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:23:53 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens110_processed_idsraw_translation_translation`
# 2025-05-27 17:24:24 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens110_processed_external_database_translation`
# 2025-05-27 17:24:24 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `111`
# 2025-05-27 17:24:28 INFO:database_manager: Raw table for `translation` on ensembl release `111` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:24:28 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens111_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:24:30 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens111_processed_idsraw_translation_translation`
# 2025-05-27 17:25:02 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens111_processed_external_database_translation`
# 2025-05-27 17:25:02 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `112`
# 2025-05-27 17:25:04 INFO:database_manager: Raw table for `translation` on ensembl release `112` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:25:04 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens112_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:25:06 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens112_processed_idsraw_translation_translation`
# 2025-05-27 17:25:37 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens112_processed_external_database_translation`
# 2025-05-27 17:25:37 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `113`
# 2025-05-27 17:25:40 INFO:database_manager: Raw table for `translation` on ensembl release `113` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:25:40 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens113_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:25:41 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens113_processed_idsraw_translation_translation`
# 2025-05-27 17:26:12 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens113_processed_external_database_translation`
# 2025-05-27 17:26:12 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `114`
# 2025-05-27 17:26:14 INFO:database_manager: Raw table for `translation` on ensembl release `114` was downloaded for following columns: translation_id, stable_id, version, transcript_id.
# 2025-05-27 17:26:14 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens114_mysql_translation_COL_stable_id_COL_transcript_id_COL_translation_id_COL_version`
# 2025-05-27 17:26:15 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens114_processed_idsraw_translation_translation`
# 2025-05-27 17:26:46 INFO:database_manager: Exporting to the following file `homo_sapiens_assembly-37.h5` with key `ens114_processed_external_database_translation`
# CPU times: user 4h 54min 43s, sys: 12min 46s, total: 5h 7min 29s
# Wall time: 6h 37min 38s

# %%
# %%time
df = dm.create_database_content()
dm.external_inst.create_template_yaml(df)
# Out:
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `79`
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `80`
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `81`
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `82`
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `83`
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `84`
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `85`
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `86`
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `87`
# 2025-05-27 17:26:46 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `88`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `89`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `90`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `91`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `92`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `93`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `94`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `95`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `96`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `97`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `98`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `99`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `100`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `101`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `102`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `103`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `104`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `105`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `106`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `107`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `108`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `109`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `110`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `111`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `112`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `113`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `gene`, ensembl release `114`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `79`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `80`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `81`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `82`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `83`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `84`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `85`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `86`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `87`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `88`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `89`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `90`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `91`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `92`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `93`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `94`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `95`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `96`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `97`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `98`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `99`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `100`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `101`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `102`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `103`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `104`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `105`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `106`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `107`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `108`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `109`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `110`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `111`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `112`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `113`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `transcript`, ensembl release `114`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `79`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `80`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `81`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `82`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `83`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `84`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `85`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `86`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `87`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `88`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `89`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `90`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `91`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `92`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `93`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `94`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `95`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `96`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `97`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `98`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `99`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `100`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `101`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `102`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `103`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `104`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `105`
# 2025-05-27 17:26:47 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `106`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `107`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `108`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `109`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `110`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `111`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `112`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `113`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `38`, form `translation`, ensembl release `114`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `79`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `80`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `81`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `82`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `83`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `84`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `85`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `86`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `87`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `88`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `89`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `90`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `91`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `92`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `93`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `94`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `95`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `96`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `97`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `98`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `99`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `100`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `101`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `102`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `103`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `104`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `105`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `106`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `107`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `108`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `109`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `110`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `111`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `112`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `113`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `gene`, ensembl release `114`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `79`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `80`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `81`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `82`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `83`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `84`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `85`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `86`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `87`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `88`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `89`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `90`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `91`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `92`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `93`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `94`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `95`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `96`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `97`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `98`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `99`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `100`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `101`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `102`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `103`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `104`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `105`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `106`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `107`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `108`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `109`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `110`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `111`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `112`
# 2025-05-27 17:26:48 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `113`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `transcript`, ensembl release `114`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `79`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `80`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `81`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `82`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `83`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `84`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `85`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `86`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `87`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `88`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `89`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `90`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `91`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `92`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `93`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `94`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `95`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `96`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `97`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `98`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `99`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `100`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `101`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `102`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `103`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `104`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `105`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `106`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `107`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `108`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `109`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `110`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `111`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `112`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `113`
# 2025-05-27 17:26:49 INFO:database_manager: Database content is being created for `homo_sapiens`, assembly `37`, form `translation`, ensembl release `114`
# 2025-05-27 17:26:49 WARNING:external_databases: File created on /Users/kemalinecik/Downloads/idtrack_temp/homo_sapiens_externals_template.yml
# Please edit the file based on requested external databases and add '_modified' to the file name. See package documentation for further detail.
# CPU times: user 1.61 s, sys: 569 ms, total: 2.18 s
# Wall time: 2.76 s

# %% [markdown]
# See the file `homo_sapiens_externals_template.yaml` in local_dir.

# %%
# !ls -l /Users/kemalinecik/Downloads/idtrack_temp
# Out:
# total 61807128
# -rw-r--r--@ 1 kemalinecik  staff  15889966491 May 27 17:26 homo_sapiens_assembly-37.h5
# -rw-r--r--@ 1 kemalinecik  staff  15755222398 May 27 14:08 homo_sapiens_assembly-38.h5
# -rw-r--r--@ 1 kemalinecik  staff        55077 May 27 17:26 homo_sapiens_externals_template.yml

# %% [markdown]
# Modify the file `blabla.yaml` in local_dir based on the instructions given in `create_template_yaml` method docstring.
#
# Here, these external databases are chosen:
# - `Clone_based_ensembl_gene`
# - `Clone_based_vega_gene`
# - `EntrezGene`
# - `HGNC Symbol`
# - `Havana gene`
# - `NCBI gene`
# - `NCBI gene (formerly Entrezgene)`
# - `RFAM`
# - `UniProtKB Gene Name`
# - `Vega gene`
# - `Vega_gene`
# - `CCDS`
# - `Havana transcript`
# - `RefSeq_mRNA`
# - `RefSeq_mRNA_predicted`
# - `RefSeq_ncRNA`
# - `RefSeq_ncRNA_predicted`
# - `Havana translation`
# - `RefSeq_peptide`
# - `RefSeq_peptide_predicted`
# - `Uniprot/SPTREMBL`
# - `Uniprot/SWISSPROT`

# %% [markdown]
# The modified file `homo_sapiens_externals_modified.yml` should be in the directory of local_dir.
#
# This yaml file is needed for initializing the graph.

# %%
# !ls -l /Users/kemalinecik/Downloads/idtrack_temp
# Out:
# total 61807256
# -rw-r--r--@ 1 kemalinecik  staff  15889966491 May 27 17:26 homo_sapiens_assembly-37.h5
# -rw-r--r--@ 1 kemalinecik  staff  15755222398 May 27 14:08 homo_sapiens_assembly-38.h5
# -rw-r--r--@ 1 kemalinecik  staff        65514 May 27 17:59 homo_sapiens_externals_modified.yml
# -rw-r--r--@ 1 kemalinecik  staff        55077 May 27 17:26 homo_sapiens_externals_template.yml

# %%
# %%time
yaml_dict = dm.external_inst.load_modified_yaml()
# Out:
# CPU times: user 73.4 ms, sys: 8.31 ms, total: 81.7 ms
# Wall time: 111 ms

# %% [markdown]
# Uses default if this step is skipped.
